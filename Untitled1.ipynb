# %% [markdown]
# <a href="https://colab.research.google.com/github/junaid-khan09/junaid-khan/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ADD TWO NUMBER

# %%
num1 = 6
num2 = 10
sum = num1 + num2
print(sum)
# Out:
# 16

# %% [markdown]
#  2. Python program to take user input and add two numbers

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
sum = num1 + num2
print(sum)
# Out:
# Enter the first number: 4
# Enter the second number: 4
# 8

# %% [markdown]
#  3. Python program to implement simple calculator

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
print("sum: ",num1+num2)
print("subtraction: ",num1-num2)
print("multiplication: ",num1*num2)
print("division: ",num1/num2)
# Out:
# Enter the first number: 5
# Enter the second number: 4
# sum:  9
# subtraction:  1
# multiplication:  20
# division:  1.25

# %% [markdown]
#  4.Python program to enter a word and check its palindrome

# %%
num1 = input("Enter the word: ")
if num1 == num1[::-1]:
 print("palindrome")
else:
 print("not palindrome")
# Out:
# Enter the word: khan
# not palindrome

# %%
from google.colab import files
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# Step 1: Upload image
uploaded = files.upload()

# Step 2: Open the uploaded image
for file_name in uploaded.keys():
    img = Image.open(file_name)
    print(f"Uploaded file: {file_name}")

# Function to display image
def show_image(image, title="Image", cmap=None):
    plt.imshow(image, cmap=cmap)
    plt.title(title)
    plt.axis("off")
    plt.show()

# Show original
show_image(img, "Original Image")

# Grayscale
gray = ImageOps.grayscale(img)
show_image(gray, "Grayscale Image", cmap="gray")

# Rotate
rotated = img.rotate(90)
show_image(rotated, "Rotated 90°")

# Flip horizontally
flipped = ImageOps.mirror(img)
show_image(flipped, "Flipped Image")

# Resize
resized = img.resize((200, 200))
show_image(resized, "Resized (200x200)")
# Out:
#      <input type="file" id="files-86571eb4-60cf-4b4e-a5c0-803a21296752" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86571eb4-60cf-4b4e-a5c0-803a21296752">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import cv2
import matplotlib.pyplot as plt
import os

# Step 1: Upload a video file
uploaded = files.upload()

# Get uploaded file name
video_path = list(uploaded.keys())[0]
print(f"Uploaded video: {video_path}")

# Step 2: Open the video using OpenCV
cap = cv2.VideoCapture(video_path)

# Step 3: Read and display first 5 frames
frame_count = 0
while frame_count < 5:
    ret, frame = cap.read()
    if not ret:
        break
    # Convert BGR (OpenCV) to RGB (matplotlib)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plt.imshow(frame_rgb)
    plt.title(f"Frame {frame_count}")
    plt.axis("off")
    plt.show()
    frame_count += 1

cap.release()
# Out:
#      <input type="file" id="files-8b6b7534-99a9-411c-9351-3fdc6aa5febb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b6b7534-99a9-411c-9351-3fdc6aa5febb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
